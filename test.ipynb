# %%
git clone https://github.com/barone04/Fish_Object_Detection.git
# Out:
#   Cell In[1], line 1
#     git clone https://github.com/barone04/Fish_Object_Detection.git
#         ^
# SyntaxError: invalid syntax
